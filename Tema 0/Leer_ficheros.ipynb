# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanCervigon/Multivariante/blob/main/Tema%200/Leer_ficheros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Leer ficheros de datos
#
# * Los ficheros csv se leen directamente desde colab
# * Los ficheros excel descargan al disco local y se suben a Google Colab manualmente

# %%
import pandas as pd

# %%
# Leer un fichero csv
# Copiar la url "raw" del fichero 

url='https://raw.githubusercontent.com/JuanCervigon/Multivariante/main/Data/titanic.csv'
df1=pd.read_csv(url)

# %%
df1.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# Leer un fichero Excel

# %%
# Leer un fichero excel de Github

# Copiar la url del fichero y añadir una "r" delante y "?raw=true" al final


url=r'https://github.com/JuanCervigon/Datos_INE/blob/main/Conjuntos_de_datos/Datos_INE.xlsx?raw=true'
df=pd.read_excel(url)
df
# Out:
#     Código           Comunidad Autónoma  T_nat  T_mort  T_mort_inf  Esperanza  \
# 0        1                    Andalucía   8.21    8.35        3.05      82.22
# 1        2                       Aragón   7.28   10.28        2.07      83.90
# 2        3      Asturias, Principado de   5.05   12.64        2.52      82.83
# 3        4              Baleares, Islas   8.08    6.67        3.20      83.71
# 4        5                     Canarias   6.37    7.10        2.69      82.79
# 5        6                    Cantabria   6.10   10.33        1.13      83.60
# 6        7              Castilla y León   5.96   11.95        2.79      84.20
# 7        8           Castilla-La Mancha   7.51    9.55        3.20      83.57
# 8        9                     Cataluña   8.09    8.48        2.55      82.83
# 9       10         Comunidad Valenciana   7.47    8.80        2.14      83.00
# 10      11                  Extremadura   7.20   10.60        2.35      82.79
# ...

# %%
# Leer un fichero excel de Github. Lectura por pasos
# 1.- Bajar el fichero excel al ordenador local
# 2.- Subir el fichero excel manualmente (drag and drop) a Colab
# 3.- Abrir el fichero excel

df2=pd.read_excel('Movilidad_estacional.xlsx')

# %%
df2.head()
